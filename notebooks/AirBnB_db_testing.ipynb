# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('Ireland_AirBnB_cleaned.sqlite')

# %%
cur = conn.cursor()

# %%
df = pd.read_csv('listings_for_db.csv')
df.head()
# Out:
#    host_response_time  host_response_rate  host_is_superhost  \
# 0        within a day           95.976389                0.0
# 1  within a few hours          100.000000                0.0
# 2      within an hour          100.000000                0.0
# 3        within a day           95.976389                0.0
# 4      within an hour          100.000000                1.0
#
#    host_listings_count  host_identity_verified  market  latitude  longitude  \
# 0                  1.0                     1.0  Dublin  53.34940   -6.34664
# 1                  1.0                     0.0  Dublin  53.34827   -6.34590
# 2                  2.0                     1.0  Dublin  53.33558   -6.36881
# 3                  1.0                     1.0  Dublin  53.33589   -6.32771
# 4                  1.0                     0.0  Dublin  53.33303   -6.32546
#
#   property_type        room_type  ...  review_scores_communication  \
# 0         House  Entire home/apt  ...                         10.0
# ...

# %%
df.shape
# Out:
# (21065, 38)

# %%
df.to_sql('listings', conn, if_exists='replace')

# %%
query = """
    SELECT COUNT(*)
    FROM listings;
"""

cur.execute(query)
cur.fetchall()
# Out:
# [(21065,)]

# %%
df = pd.read_sql_query('SELECT * FROM listings', conn)
df.drop(columns='index', inplace=True)
df.head()
# Out:
#    host_response_time  host_response_rate  host_is_superhost  \
# 0        within a day           95.976389                0.0
# 1  within a few hours          100.000000                0.0
# 2      within an hour          100.000000                0.0
# 3        within a day           95.976389                0.0
# 4      within an hour          100.000000                1.0
#
#    host_listings_count  host_identity_verified  market  latitude  longitude  \
# 0                  1.0                     1.0  Dublin  53.34940   -6.34664
# 1                  1.0                     0.0  Dublin  53.34827   -6.34590
# 2                  2.0                     1.0  Dublin  53.33558   -6.36881
# 3                  1.0                     1.0  Dublin  53.33589   -6.32771
# 4                  1.0                     0.0  Dublin  53.33303   -6.32546
#
#   property_type        room_type  ...  review_scores_communication  \
# 0         House  Entire home/apt  ...                         10.0
# ...
